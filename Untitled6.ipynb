# %% [markdown]
# <a href="https://colab.research.google.com/github/Raka7317/set_project_work/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ==========================================================
# FULL HYBRID PHISHING URL DETECTION SYSTEM
# WITH FULL METRICS + WORKING DRIFT INDEX PRINTING
# ==========================================================

print("\n================ STEP 0: SETUP ================")

from google.colab import drive
drive.mount("/content/drive")

import os, math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import IsolationForest
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, roc_curve, auc, confusion_matrix
)
from scipy.sparse import hstack

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"✔ Device: {device}")

# ==========================================================
print("\n================ STEP 1: DATA LOADING ================")

BASE = "/content/drive/MyDrive/data"
TRAIN = os.path.join(BASE, "train.csv")
TEST  = os.path.join(BASE, "test.csv")
PHI   = os.path.join(BASE, "phiusiil.csv")

def load_data(path):
    df = pd.read_csv(path)
    if "URL" in df.columns:
        df = df.rename(columns={"URL":"url","label":"labels"})
    df = df[["url","labels"]].dropna()
    df["labels"] = df["labels"].astype(int)
    print(f"{os.path.basename(path)} → {df.shape}")
    return df

train_df = load_data(TRAIN)
test_df  = load_data(TEST)
phi_df   = load_data(PHI)

# ==========================================================
print("\n================ STEP 2: LEXICAL FEATURES ================")

def lexical_features(url):
    return [
        len(url),
        sum(c.isdigit() for c in url),
        sum(not c.isalnum() for c in url),
        url.count('.'),
        url.count('-'),
        url.count('%'),
        url.count('@'),
        math.log2(len(url)+1)
    ]

X_lex_train = np.array([lexical_features(u) for u in train_df.url])
X_lex_test  = np.array([lexical_features(u) for u in test_df.url])
X_lex_phi   = np.array([lexical_features(u) for u in phi_df.url])

# ==========================================================
print("\n================ STEP 3: CHAR N-GRAM TF-IDF ================")

tfidf = TfidfVectorizer(analyzer="char", ngram_range=(3,5), min_df=5)
X_ng_train = tfidf.fit_transform(train_df.url)
X_ng_test  = tfidf.transform(test_df.url)
X_ng_phi   = tfidf.transform(phi_df.url)

# ==========================================================
print("\n================ STEP 4: FEATURE FUSION ================")

X_train_ml = hstack([X_ng_train, X_lex_train]).tocsr()
X_test_ml  = hstack([X_ng_test, X_lex_test]).tocsr()
X_phi_ml   = hstack([X_ng_phi, X_lex_phi]).tocsr()

y_train, y_test, y_phi = train_df.labels, test_df.labels, phi_df.labels

# ==========================================================
print("\n================ STEP 5: ONLINE ML CLASSIFIER ================")

clf = SGDClassifier(loss="log_loss")
clf.fit(X_train_ml, y_train)

p_ml_test = clf.predict_proba(X_test_ml)[:,1]
p_ml_phi  = clf.predict_proba(X_phi_ml)[:,1]

# ==========================================================
print("\n================ STEP 6: ISOLATION FOREST ================")

iso = IsolationForest(contamination=0.1, random_state=42)
iso.fit(X_lex_train[y_train==0])

a_test = -iso.score_samples(X_lex_test)
a_phi  = -iso.score_samples(X_lex_phi)

# ==========================================================
print("\n================ STEP 7: TINY TCN + ATTENTION ================")

MAX_LEN = 128
chars = sorted(set("".join(train_df.url.astype(str))))
char2idx = {c:i+1 for i,c in enumerate(chars)}
char2idx["<PAD>"] = 0

def encode(u):
    s=[char2idx.get(c,0) for c in str(u)[:MAX_LEN]]
    return s+[0]*(MAX_LEN-len(s))

class URLDS(Dataset):
    def __init__(self, urls, y):
        self.X=[encode(u) for u in urls]
        self.y=y.values
    def __len__(self): return len(self.y)
    def __getitem__(self,i):
        return torch.tensor(self.X[i]), torch.tensor(self.y[i],dtype=torch.float)

train_dl=DataLoader(URLDS(train_df.url,y_train),256,shuffle=True)
test_dl =DataLoader(URLDS(test_df.url,y_test),256)
phi_dl  =DataLoader(URLDS(phi_df.url,y_phi),256)

class TinyTCNAttn(nn.Module):
    def __init__(self,v):
        super().__init__()
        self.emb=nn.Embedding(v,64,padding_idx=0)
        self.conv=nn.Conv1d(64,64,3,padding=1)
        self.attn=nn.Linear(64,1)
        self.fc=nn.Linear(64,1)
    def forward(self,x):
        x=self.emb(x).transpose(1,2)
        x=torch.relu(self.conv(x)).transpose(1,2)
        w=torch.softmax(self.attn(x).squeeze(-1),1)
        return self.fc((x*w.unsqueeze(-1)).sum(1)).squeeze()

model=TinyTCNAttn(len(char2idx)).to(device)
opt=torch.optim.Adam(model.parameters(),lr=0.001)
lossf=nn.BCEWithLogitsLoss()

for e in range(3):
    for X,y in train_dl:
        X,y=X.to(device),y.to(device)
        opt.zero_grad()
        loss=lossf(model(X),y)
        loss.backward()
        opt.step()
    print(f"Epoch {e+1} done")

def dl_scores(dl):
    model.eval(); s=[]
    with torch.no_grad():
        for X,_ in dl:
            X=X.to(device)
            s.extend(torch.sigmoid(model(X)).cpu().numpy())
    return np.array(s)

p_dl_test = dl_scores(test_dl)
p_dl_phi  = dl_scores(phi_dl)

# ==========================================================
print("\n================ STEP 8: SCORE FUSION ================")

α=0.6
S_test = α*p_ml_test + (1-α)*p_dl_test*(1-a_test/np.max(a_test))
S_phi  = α*p_ml_phi  + (1-α)*p_dl_phi *(1-a_phi/np.max(a_phi))

yhat_test=(S_test>0.5).astype(int)
yhat_phi =(S_phi>0.5).astype(int)

# ================= PRINT METRICS =================

def print_metrics(y_true, y_pred, scores, name):
    print(f"\n------ {name} METRICS ------")
    print("Accuracy :", accuracy_score(y_true,y_pred))
    print("Precision:", precision_score(y_true,y_pred))
    print("Recall   :", recall_score(y_true,y_pred))
    print("F1 Score :", f1_score(y_true,y_pred))
    fpr,tpr,_=roc_curve(y_true,scores)
    print("AUC      :", auc(fpr,tpr))

print_metrics(y_test,yhat_test,S_test,"HYBRID TEST")
print_metrics(y_phi,yhat_phi,S_phi,"HYBRID PHI")

# ==========================================================
print("\n================ STEP 9: CONCEPT DRIFT (WORKING) ================")

class PageHinkley:
    def __init__(self,delta=0.01,lam=5):
        self.delta=delta
        self.lam=lam
        self.reset()

    def reset(self):
        self.mean=0
        self.sum=0
        self.min=0
        self.t=0

    def update(self,x):
        self.t+=1
        self.mean+=(x-self.mean)/self.t
        self.sum+=x-self.mean-self.delta
        self.min=min(self.min,self.sum)

        if self.sum-self.min>self.lam:
            self.reset()
            return True
        return False

ph=PageHinkley()

losses=[]
drifts=[]

print("\n🔍 Monitoring Stream for Drift...\n")

for i in range(len(y_test)):
    err=int(yhat_test[i]!=y_test.iloc[i])
    losses.append(err)

    if ph.update(err):
        drifts.append(i)
        print(f"🚨 Drift detected at index: {i}")

plt.figure(figsize=(12,5))
plt.plot(losses,label="Prediction Error")
for d in drifts:
    plt.axvline(d,color="red",ls="--")
plt.title("Concept Drift Detection (Page-Hinkley)")
plt.xlabel("Sample Index")
plt.ylabel("Error")
plt.legend()
plt.show()

print("\n================ DRIFT SUMMARY ================")
print("Total Drift Points:", len(drifts))
print("Drift Index List :", drifts)
print("Average Stream Error:", np.mean(losses))

print("\n================ PIPELINE COMPLETED SUCCESSFULLY ================")
# Out:
# ================ STEP 0: SETUP ================
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✔ Device: cpu
#
# ================ STEP 1: DATA LOADING ================
# train.csv → (160000, 2)
# test.csv → (160000, 2)
# phiusiil.csv → (235795, 2)
#
# ================ STEP 2: LEXICAL FEATURES ================
#
# ================ STEP 3: CHAR N-GRAM TF-IDF ================
#
# ================ STEP 4: FEATURE FUSION ================
#
# ================ STEP 5: ONLINE ML CLASSIFIER ================
#
# ================ STEP 6: ISOLATION FOREST ================
#
# ================ STEP 7: TINY TCN + ATTENTION ================
# Epoch 1 done
# Epoch 2 done
# Epoch 3 done
#
# ================ STEP 8: SCORE FUSION ================
#
# ------ HYBRID TEST METRICS ------
# Accuracy : 0.8903625
# Precision: 0.909302996146688
# Recall   : 0.867225
# F1 Score : 0.8877656783836005
# AUC      : 0.9636421234375
#
# ------ HYBRID PHI METRICS ------
# Accuracy : 0.7976547424669734
# Precision: 0.7386714727085479
# Recall   : 0.9999480904708936
# F1 Score : 0.8496776917308868
# AUC      : 0.9214531162531137
#
# ================ STEP 9: CONCEPT DRIFT (WORKING) ================
#
# 🔍 Monitoring Stream for Drift...
#
# 🚨 Drift detected at index: 198
# 🚨 Drift detected at index: 429
# 🚨 Drift detected at index: 752
# 🚨 Drift detected at index: 1073
# 🚨 Drift detected at index: 1532
# 🚨 Drift detected at index: 1936
# 🚨 Drift detected at index: 2474
# 🚨 Drift detected at index: 3642
# 🚨 Drift detected at index: 4430
# 🚨 Drift detected at index: 4713
# 🚨 Drift detected at index: 5511
# 🚨 Drift detected at index: 6063
# 🚨 Drift detected at index: 6714
# 🚨 Drift detected at index: 7709
# 🚨 Drift detected at index: 7775
# 🚨 Drift detected at index: 7918
# 🚨 Drift detected at index: 8192
# 🚨 Drift detected at index: 8439
# 🚨 Drift detected at index: 8791
# 🚨 Drift detected at index: 9059
# 🚨 Drift detected at index: 10077
# 🚨 Drift detected at index: 10464
# 🚨 Drift detected at index: 11602
# 🚨 Drift detected at index: 12314
# 🚨 Drift detected at index: 12431
# 🚨 Drift detected at index: 13055
# 🚨 Drift detected at index: 14146
# 🚨 Drift detected at index: 14324
# 🚨 Drift detected at index: 14559
# 🚨 Drift detected at index: 14790
# 🚨 Drift detected at index: 15050
# 🚨 Drift detected at index: 15448
# 🚨 Drift detected at index: 16279
# 🚨 Drift detected at index: 16545
# 🚨 Drift detected at index: 16791
# 🚨 Drift detected at index: 16926
# 🚨 Drift detected at index: 17098
# 🚨 Drift detected at index: 17588
# 🚨 Drift detected at index: 17662
# 🚨 Drift detected at index: 18703
# 🚨 Drift detected at index: 19474
# 🚨 Drift detected at index: 19526
# 🚨 Drift detected at index: 19629
# 🚨 Drift detected at index: 20139
# 🚨 Drift detected at index: 20282
# 🚨 Drift detected at index: 20765
# 🚨 Drift detected at index: 20950
# 🚨 Drift detected at index: 21110
# 🚨 Drift detected at index: 21473
# 🚨 Drift detected at index: 21979
# 🚨 Drift detected at index: 23181
# 🚨 Drift detected at index: 23412
# 🚨 Drift detected at index: 23763
# 🚨 Drift detected at index: 24097
# 🚨 Drift detected at index: 25768
# 🚨 Drift detected at index: 26085
# 🚨 Drift detected at index: 26164
# 🚨 Drift detected at index: 26861
# 🚨 Drift detected at index: 27001
# 🚨 Drift detected at index: 27538
# 🚨 Drift detected at index: 27900
# 🚨 Drift detected at index: 28586
# 🚨 Drift detected at index: 29092
# 🚨 Drift detected at index: 29277
# 🚨 Drift detected at index: 29626
# 🚨 Drift detected at index: 30721
# 🚨 Drift detected at index: 31045
# 🚨 Drift detected at index: 31568
# 🚨 Drift detected at index: 31730
# 🚨 Drift detected at index: 31893
# 🚨 Drift detected at index: 32114
# 🚨 Drift detected at index: 32298
# 🚨 Drift detected at index: 32408
# 🚨 Drift detected at index: 33034
# 🚨 Drift detected at index: 33136
# 🚨 Drift detected at index: 33705
# 🚨 Drift detected at index: 34168
# 🚨 Drift detected at index: 34366
# 🚨 Drift detected at index: 34833
# 🚨 Drift detected at index: 35135
# 🚨 Drift detected at index: 35505
# 🚨 Drift detected at index: 36390
# 🚨 Drift detected at index: 36540
# 🚨 Drift detected at index: 37085
# 🚨 Drift detected at index: 37748
# 🚨 Drift detected at index: 38349
# 🚨 Drift detected at index: 38742
# 🚨 Drift detected at index: 38857
# 🚨 Drift detected at index: 39261
# 🚨 Drift detected at index: 39682
# 🚨 Drift detected at index: 39851
# 🚨 Drift detected at index: 40726
# 🚨 Drift detected at index: 41196
# 🚨 Drift detected at index: 41364
# 🚨 Drift detected at index: 41684
# 🚨 Drift detected at index: 42420
# 🚨 Drift detected at index: 42935
# 🚨 Drift detected at index: 43594
# 🚨 Drift detected at index: 43765
# 🚨 Drift detected at index: 44572
# 🚨 Drift detected at index: 44911
# 🚨 Drift detected at index: 45110
# 🚨 Drift detected at index: 45700
# 🚨 Drift detected at index: 46173
# 🚨 Drift detected at index: 46471
# 🚨 Drift detected at index: 47581
# 🚨 Drift detected at index: 47661
# 🚨 Drift detected at index: 48028
# 🚨 Drift detected at index: 48307
# 🚨 Drift detected at index: 48572
# 🚨 Drift detected at index: 48719
# 🚨 Drift detected at index: 49204
# 🚨 Drift detected at index: 49706
# 🚨 Drift detected at index: 49821
# 🚨 Drift detected at index: 50469
# 🚨 Drift detected at index: 50796
# 🚨 Drift detected at index: 51238
# 🚨 Drift detected at index: 51406
# 🚨 Drift detected at index: 51575
# 🚨 Drift detected at index: 51856
# 🚨 Drift detected at index: 52333
# 🚨 Drift detected at index: 53180
# 🚨 Drift detected at index: 53353
# 🚨 Drift detected at index: 53537
# 🚨 Drift detected at index: 55844
# 🚨 Drift detected at index: 56173
# 🚨 Drift detected at index: 56724
# 🚨 Drift detected at index: 58461
# 🚨 Drift detected at index: 58674
# 🚨 Drift detected at index: 58964
# 🚨 Drift detected at index: 59282
# 🚨 Drift detected at index: 59547
# 🚨 Drift detected at index: 59777
# 🚨 Drift detected at index: 60028
# 🚨 Drift detected at index: 60308
# 🚨 Drift detected at index: 60596
# 🚨 Drift detected at index: 60939
# 🚨 Drift detected at index: 61271
# 🚨 Drift detected at index: 61576
# 🚨 Drift detected at index: 61981
# 🚨 Drift detected at index: 62860
# 🚨 Drift detected at index: 63512
# 🚨 Drift detected at index: 63870
# 🚨 Drift detected at index: 64089
# 🚨 Drift detected at index: 64186
# 🚨 Drift detected at index: 64813
# 🚨 Drift detected at index: 64977
# 🚨 Drift detected at index: 65918
# 🚨 Drift detected at index: 66683
# 🚨 Drift detected at index: 67199
# 🚨 Drift detected at index: 67704
# 🚨 Drift detected at index: 67923
# 🚨 Drift detected at index: 68757
# 🚨 Drift detected at index: 69047
# 🚨 Drift detected at index: 69783
# 🚨 Drift detected at index: 69998
# 🚨 Drift detected at index: 70562
# 🚨 Drift detected at index: 71068
# 🚨 Drift detected at index: 71274
# 🚨 Drift detected at index: 71445
# 🚨 Drift detected at index: 72044
# 🚨 Drift detected at index: 72594
# 🚨 Drift detected at index: 72671
# 🚨 Drift detected at index: 72823
# 🚨 Drift detected at index: 73277
# 🚨 Drift detected at index: 73604
# 🚨 Drift detected at index: 74438
# 🚨 Drift detected at index: 74857
# 🚨 Drift detected at index: 75200
# 🚨 Drift detected at index: 75328
# 🚨 Drift detected at index: 75405
# 🚨 Drift detected at index: 75824
# 🚨 Drift detected at index: 76344
# 🚨 Drift detected at index: 76422
# 🚨 Drift detected at index: 76523
# 🚨 Drift detected at index: 76742
# 🚨 Drift detected at index: 76875
# 🚨 Drift detected at index: 77392
# 🚨 Drift detected at index: 77995
# 🚨 Drift detected at index: 78604
# 🚨 Drift detected at index: 79007
# 🚨 Drift detected at index: 79104
# 🚨 Drift detected at index: 79860
# 🚨 Drift detected at index: 80051
# 🚨 Drift detected at index: 80263
# 🚨 Drift detected at index: 81376
# 🚨 Drift detected at index: 81924
# 🚨 Drift detected at index: 82706
# 🚨 Drift detected at index: 82906
# 🚨 Drift detected at index: 83533
# 🚨 Drift detected at index: 84008
# 🚨 Drift detected at index: 84185
# 🚨 Drift detected at index: 85026
# 🚨 Drift detected at index: 85245
# 🚨 Drift detected at index: 85580
# 🚨 Drift detected at index: 85908
# 🚨 Drift detected at index: 86230
# 🚨 Drift detected at index: 87031
# 🚨 Drift detected at index: 87433
# 🚨 Drift detected at index: 87976
# 🚨 Drift detected at index: 88561
# 🚨 Drift detected at index: 88685
# 🚨 Drift detected at index: 88897
# 🚨 Drift detected at index: 89077
# 🚨 Drift detected at index: 89473
# 🚨 Drift detected at index: 89745
# 🚨 Drift detected at index: 89838
# 🚨 Drift detected at index: 90359
# 🚨 Drift detected at index: 90641
# 🚨 Drift detected at index: 91458
# 🚨 Drift detected at index: 91544
# 🚨 Drift detected at index: 91636
# 🚨 Drift detected at index: 92110
# 🚨 Drift detected at index: 92989
# 🚨 Drift detected at index: 93265
# 🚨 Drift detected at index: 93688
# 🚨 Drift detected at index: 94268
# 🚨 Drift detected at index: 95103
# 🚨 Drift detected at index: 95326
# 🚨 Drift detected at index: 95434
# 🚨 Drift detected at index: 95637
# 🚨 Drift detected at index: 95919
# 🚨 Drift detected at index: 96591
# 🚨 Drift detected at index: 96785
# 🚨 Drift detected at index: 97406
# 🚨 Drift detected at index: 97517
# 🚨 Drift detected at index: 97884
# 🚨 Drift detected at index: 99010
# 🚨 Drift detected at index: 99047
# 🚨 Drift detected at index: 99186
# 🚨 Drift detected at index: 99313
# 🚨 Drift detected at index: 99471
# 🚨 Drift detected at index: 100513
# 🚨 Drift detected at index: 100984
# 🚨 Drift detected at index: 101129
# 🚨 Drift detected at index: 101241
# 🚨 Drift detected at index: 102202
# 🚨 Drift detected at index: 102790
# 🚨 Drift detected at index: 103369
# 🚨 Drift detected at index: 103791
# 🚨 Drift detected at index: 104394
# 🚨 Drift detected at index: 104477
# 🚨 Drift detected at index: 104603
# 🚨 Drift detected at index: 105367
# 🚨 Drift detected at index: 105451
# 🚨 Drift detected at index: 106107
# 🚨 Drift detected at index: 106303
# 🚨 Drift detected at index: 107518
# 🚨 Drift detected at index: 107719
# 🚨 Drift detected at index: 107909
# 🚨 Drift detected at index: 108210
# 🚨 Drift detected at index: 108865
# 🚨 Drift detected at index: 109844
# 🚨 Drift detected at index: 110584
# 🚨 Drift detected at index: 111222
# 🚨 Drift detected at index: 111285
# 🚨 Drift detected at index: 111564
# 🚨 Drift detected at index: 112011
# 🚨 Drift detected at index: 112358
# 🚨 Drift detected at index: 112479
# 🚨 Drift detected at index: 112749
# 🚨 Drift detected at index: 113481
# 🚨 Drift detected at index: 114341
# 🚨 Drift detected at index: 114845
# 🚨 Drift detected at index: 115085
# 🚨 Drift detected at index: 115327
# 🚨 Drift detected at index: 115490
# 🚨 Drift detected at index: 115567
# 🚨 Drift detected at index: 115770
# 🚨 Drift detected at index: 116048
# 🚨 Drift detected at index: 116193
# 🚨 Drift detected at index: 117423
# 🚨 Drift detected at index: 117598
# 🚨 Drift detected at index: 117932
# 🚨 Drift detected at index: 118328
# 🚨 Drift detected at index: 118672
# 🚨 Drift detected at index: 118803
# 🚨 Drift detected at index: 118877
# 🚨 Drift detected at index: 120341
# 🚨 Drift detected at index: 120410
# 🚨 Drift detected at index: 121284
# 🚨 Drift detected at index: 121872
# 🚨 Drift detected at index: 122797
# 🚨 Drift detected at index: 122983
# 🚨 Drift detected at index: 123094
# 🚨 Drift detected at index: 123290
# 🚨 Drift detected at index: 124594
# 🚨 Drift detected at index: 124968
# 🚨 Drift detected at index: 125313
# 🚨 Drift detected at index: 125435
# 🚨 Drift detected at index: 125662
# 🚨 Drift detected at index: 126080
# 🚨 Drift detected at index: 126293
# 🚨 Drift detected at index: 126399
# 🚨 Drift detected at index: 126767
# 🚨 Drift detected at index: 127128
# 🚨 Drift detected at index: 127458
# 🚨 Drift detected at index: 127703
# 🚨 Drift detected at index: 128137
# 🚨 Drift detected at index: 128313
# 🚨 Drift detected at index: 128393
# 🚨 Drift detected at index: 129119
# 🚨 Drift detected at index: 129561
# 🚨 Drift detected at index: 130504
# 🚨 Drift detected at index: 131391
# 🚨 Drift detected at index: 131833
# 🚨 Drift detected at index: 132001
# 🚨 Drift detected at index: 132077
# 🚨 Drift detected at index: 133623
# 🚨 Drift detected at index: 134734
# 🚨 Drift detected at index: 134867
# 🚨 Drift detected at index: 135165
# 🚨 Drift detected at index: 135622
# 🚨 Drift detected at index: 135850
# 🚨 Drift detected at index: 136405
# 🚨 Drift detected at index: 136628
# 🚨 Drift detected at index: 137065
# 🚨 Drift detected at index: 137388
# 🚨 Drift detected at index: 137807
# 🚨 Drift detected at index: 138336
# 🚨 Drift detected at index: 138714
# 🚨 Drift detected at index: 138830
# 🚨 Drift detected at index: 139477
# 🚨 Drift detected at index: 139989
# 🚨 Drift detected at index: 140947
# 🚨 Drift detected at index: 141156
# 🚨 Drift detected at index: 141743
# 🚨 Drift detected at index: 142231
# 🚨 Drift detected at index: 142567
# 🚨 Drift detected at index: 143757
# 🚨 Drift detected at index: 144157
# 🚨 Drift detected at index: 144532
# 🚨 Drift detected at index: 144698
# 🚨 Drift detected at index: 144964
# 🚨 Drift detected at index: 145233
# 🚨 Drift detected at index: 145607
# 🚨 Drift detected at index: 146042
# 🚨 Drift detected at index: 146240
# 🚨 Drift detected at index: 146550
# 🚨 Drift detected at index: 146926
# 🚨 Drift detected at index: 147699
# 🚨 Drift detected at index: 148297
# 🚨 Drift detected at index: 148399
# 🚨 Drift detected at index: 149349
# 🚨 Drift detected at index: 149553
# 🚨 Drift detected at index: 150690
# 🚨 Drift detected at index: 150992
# 🚨 Drift detected at index: 151139
# 🚨 Drift detected at index: 151236
# 🚨 Drift detected at index: 151336
# 🚨 Drift detected at index: 151917
# 🚨 Drift detected at index: 152251
# 🚨 Drift detected at index: 152348
# 🚨 Drift detected at index: 152949
# 🚨 Drift detected at index: 153132
# 🚨 Drift detected at index: 153244
# 🚨 Drift detected at index: 154062
# 🚨 Drift detected at index: 154416
# 🚨 Drift detected at index: 154894
# 🚨 Drift detected at index: 155390
# 🚨 Drift detected at index: 155790
# 🚨 Drift detected at index: 156374
# 🚨 Drift detected at index: 156736
# 🚨 Drift detected at index: 156967
# 🚨 Drift detected at index: 157737
# 🚨 Drift detected at index: 157954
# 🚨 Drift detected at index: 158282
# 🚨 Drift detected at index: 158387
# 🚨 Drift detected at index: 158463
# 🚨 Drift detected at index: 158988
# 🚨 Drift detected at index: 159494
# ================ DRIFT SUMMARY ================
# Total Drift Points: 371
# Drift Index List : [198, 429, 752, 1073, 1532, 1936, 2474, 3642, 4430, 4713, 5511, 6063, 6714, 7709, 7775, 7918, 8192, 8439, 8791, 9059, 10077, 10464, 11602, 12314, 12431, 13055, 14146, 14324, 14559, 14790, 15050, 15448, 16279, 16545, 16791, 16926, 17098, 17588, 17662, 18703, 19474, 19526, 19629, 20139, 20282, 20765, 20950, 21110, 21473, 21979, 23181, 23412, 23763, 24097, 25768, 26085, 26164, 26861, 27001, 27538, 27900, 28586, 29092, 29277, 29626, 30721, 31045, 31568, 31730, 31893, 32114, 32298, 32408, 33034, 33136, 33705, 34168, 34366, 34833, 35135, 35505, 36390, 36540, 37085, 37748, 38349, 38742, 38857, 39261, 39682, 39851, 40726, 41196, 41364, 41684, 42420, 42935, 43594, 43765, 44572, 44911, 45110, 45700, 46173, 46471, 47581, 47661, 48028, 48307, 48572, 48719, 49204, 49706, 49821, 50469, 50796, 51238, 51406, 51575, 51856, 52333, 53180, 53353, 53537, 55844, 56173, 56724, 58461, 58674, 58964, 59282, 59547, 59777, 60028, 60308, 60596, 60939, 61271, 61576, 61981, 62860, 63512, 63870, 64089, 64186, 64813, 64977, 65918, 66683, 67199, 67704, 67923, 68757, 69047, 69783, 69998, 70562, 71068, 71274, 71445, 72044, 72594, 72671, 72823, 73277, 73604, 74438, 74857, 75200, 75328, 75405, 75824, 76344, 76422, 76523, 76742, 76875, 77392, 77995, 78604, 79007, 79104, 79860, 80051, 80263, 81376, 81924, 82706, 82906, 83533, 84008, 84185, 85026, 85245, 85580, 85908, 86230, 87031, 87433, 87976, 88561, 88685, 88897, 89077, 89473, 89745, 89838, 90359, 90641, 91458, 91544, 91636, 92110, 92989, 93265, 93688, 94268, 95103, 95326, 95434, 95637, 95919, 96591, 96785, 97406, 97517, 97884, 99010, 99047, 99186, 99313, 99471, 100513, 100984, 101129, 101241, 102202, 102790, 103369, 103791, 104394, 104477, 104603, 105367, 105451, 106107, 106303, 107518, 107719, 107909, 108210, 108865, 109844, 110584, 111222, 111285, 111564, 112011, 112358, 112479, 112749, 113481, 114341, 114845, 115085, 115327, 115490, 115567, 115770, 116048, 116193, 117423, 117598, 117932, 118328, 118672, 118803, 118877, 120341, 120410, 121284, 121872, 122797, 122983, 123094, 123290, 124594, 124968, 125313, 125435, 125662, 126080, 126293, 126399, 126767, 127128, 127458, 127703, 128137, 128313, 128393, 129119, 129561, 130504, 131391, 131833, 132001, 132077, 133623, 134734, 134867, 135165, 135622, 135850, 136405, 136628, 137065, 137388, 137807, 138336, 138714, 138830, 139477, 139989, 140947, 141156, 141743, 142231, 142567, 143757, 144157, 144532, 144698, 144964, 145233, 145607, 146042, 146240, 146550, 146926, 147699, 148297, 148399, 149349, 149553, 150690, 150992, 151139, 151236, 151336, 151917, 152251, 152348, 152949, 153132, 153244, 154062, 154416, 154894, 155390, 155790, 156374, 156736, 156967, 157737, 157954, 158282, 158387, 158463, 158988, 159494]
# Average Stream Error: 0.1096375
#
# ================ PIPELINE COMPLETED SUCCESSFULLY ================
